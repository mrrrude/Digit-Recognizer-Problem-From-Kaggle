# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow import keras
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/digit-recognizer/sample_submission.csv
# /kaggle/input/digit-recognizer/test.csv
# /kaggle/input/digit-recognizer/train.csv

# %%
train_data=pd.read_csv('../input/digit-recognizer/train.csv')
test_data=pd.read_csv('../input/digit-recognizer/test.csv')

# %%
train_label=train_data['label']
train_X=train_data.drop('label', axis=1)

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(784, )),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
    
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
model.fit(train_X, train_label, epochs=20)
# Out:
# Train on 42000 samples
# Epoch 1/10
# 42000/42000 [==============================] - 5s 110us/sample - loss: 0.8416
# Epoch 2/10
# 42000/42000 [==============================] - 4s 94us/sample - loss: 0.2352
# Epoch 3/10
# 42000/42000 [==============================] - 4s 93us/sample - loss: 0.1780
# Epoch 4/10
# 42000/42000 [==============================] - 4s 93us/sample - loss: 0.1559
# Epoch 5/10
# 42000/42000 [==============================] - 4s 94us/sample - loss: 0.1334
# Epoch 6/10
# 42000/42000 [==============================] - 4s 102us/sample - loss: 0.1156
# Epoch 7/10
# 42000/42000 [==============================] - 4s 96us/sample - loss: 0.1062
# Epoch 8/10
# 42000/42000 [==============================] - 4s 94us/sample - loss: 0.0994
# Epoch 9/10
# 42000/42000 [==============================] - 4s 97us/sample - loss: 0.0849
# Epoch 10/10
# 42000/42000 [==============================] - 5s 108us/sample - loss: 0.0808

# %%
submission_data=model.predict_classes([test_data])

# %%
print(submission_data.shape)
# Out:
# (28000,)
# array([2, 0, 9, ..., 3, 9, 2])

# %%
submissions = pd.DataFrame({'ImageId':list(range(1,len(submission_data) + 1)), "Label": submission_data})

# %%
print(submissions.shape)
# Out:
# (28000, 2)

# %%
submissions.to_csv("submission.csv", index=False, header=True)
